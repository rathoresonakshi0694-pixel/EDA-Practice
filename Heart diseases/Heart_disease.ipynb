# %% [markdown]
# Heart Disease Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("heart-disease.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.shape
# Out:
# (303, 14)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
new = df[df.duplicated()]
new
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 164      2   4     2       1

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# - There is one duplicate value
# - There is no null value

# %% [markdown]
# Univeriate Analysis

# %%
sns.countplot(x='sex', data=df)
plt.title("Distribution of male and female")
df['sex'].value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
sns.countplot(x='cp', data=df)
plt.title("Distribution of chest pain type")
df['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
sns.countplot(x='fbs', data=df)
plt.title("Distribution of sugar level")
df['fbs'].value_counts()
# Out:
# fbs
# 0    258
# 1     45
# Name: count, dtype: int64

# %%
sns.countplot(x='restecg', data=df)
plt.title("Distribution for resting electrocardiographic results")
df['restecg'].value_counts()
# Out:
# restecg
# 1    152
# 0    147
# 2      4
# Name: count, dtype: int64

# %%
sns.countplot(x='exang', data=df)
plt.title("Distribution for exercise induced angina")
df['exang'].value_counts()
# Out:
# exang
# 0    204
# 1     99
# Name: count, dtype: int64

# %%
sns.countplot(x='slope', data=df)
plt.title("Distribution for  peak exercise ST segment")
df['slope'].value_counts()
# Out:
# slope
# 2    142
# 1    140
# 0     21
# Name: count, dtype: int64

# %%
sns.countplot(x='ca', data=df)
plt.title("Number of major vessels (0-3) colored by flourosopy")
df['ca'].value_counts()
# Out:
# ca
# 0    175
# 1     65
# 2     38
# 3     20
# 4      5
# Name: count, dtype: int64

# %%
sns.countplot(x='thal', data=df)
plt.title("Distribution for defects")
df['thal'].value_counts()
# Out:
# thal
# 2    166
# 3    117
# 1     18
# 0      2
# Name: count, dtype: int64

# %%
sns.countplot(x='target', data=df)
plt.title("Distribution of diseased people")
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
sns.histplot(df['age'],kde=True)
plt.title("Distribution of age")
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %%
sns.histplot(df['chol'],kde=True)
plt.title("Distribution of serum cholestoral in mg/dl")
# Out:
# Text(0.5, 1.0, 'Distribution of serum cholestoral in mg/dl')

# %%
sns.histplot(df['trestbps'],kde=True)
plt.title("Distribution of blood presure")
# Out:
# Text(0.5, 1.0, 'Distribution of blood presure')

# %%
sns.histplot(df['thalach'],kde=True)
plt.title("Distribution of maximum heart rate achieved")
# Out:
# Text(0.5, 1.0, 'Distribution of maximum heart rate achieved')

# %%
sns.histplot(df['oldpeak'],kde=True)
plt.title("Distribution of  ST depression induced by exercise relative to rest")
# Out:
# Text(0.5, 1.0, 'Distribution of  ST depression induced by exercise relative to rest')

# %% [markdown]
# #Observation
# - Males are more then female
# - Maximum number of people(143) have typical angina
# - Less people have asymptomatic
# - Less number of people have sugar level more then 120mg/dl
# - 147 people have normal resting result
# - 152 people have ST-T wave abnormality
# - Less number of people have exercise induced angina
# - More number od people have downsloping or falt ST segment
# - 175 people have zero major vessels
# - Only 5 people have four major vessels
# - 166 people have reversable defects
# - 117 people have the label
# - Very few people have normal and fixed defects
# - 165 people have disease
# - 138 people have no disease

# %% [markdown]
# - More people have age between 45-65 years
# - Maximum age is 77 years
# - Minimun age is 29 years
# - Mean of the age is 54
# - Serum cholestrol lies between 200 to 300 mg/dl
# - Blood pressure normally lies between 120-140
# - Very few people have blood pressure higher then 200
# - Heart rate lies between 140-175
# - Very few people have ST depression

# %% [markdown]
# Bivariate Analysis

# %%
cd = pd.crosstab(df['sex'],df['cp'])
sns.heatmap(cd,annot = True,cmap= 'Blues')
plt.title('Sex vs chest pain type')
plt.xlabel('chest pain type')
# Out:
# Text(0.5, 23.52222222222222, 'chest pain type')

# %%
cd = pd.crosstab(df['sex'],df['fbs'])
sns.heatmap(cd,annot = True,cmap= 'Blues')
plt.title('Sex vs Blood sugar level')
# Out:
# Text(0.5, 1.0, 'Sex vs Blood sugar level')

# %%
cd = pd.crosstab(df['sex'],df['restecg'])
sns.heatmap(cd)
plt.title('Sex vs resting electrocardiographic results')
# Out:
# Text(0.5, 1.0, 'Sex vs resting electrocardiographic results')

# %%
cd = pd.crosstab(df['sex'],df['exang'])
sns.heatmap(cd)
plt.title('Sex vs exercise induced angina')
# Out:
# Text(0.5, 1.0, 'Sex vs exercise induced angina')

# %%
cd = pd.crosstab(df['sex'],df['slope'])
sns.heatmap(cd)
plt.title('Sex vs slope')
# Out:
# Text(0.5, 1.0, 'Sex vs slope')

# %%
cd = pd.crosstab(df['sex'],df['ca'])
sns.heatmap(cd)
plt.title('Sex vs number of major vessels')
# Out:
# Text(0.5, 1.0, 'Sex vs number of major vessels')

# %%
cd = pd.crosstab(df['sex'],df['thal'])
sns.heatmap(cd)
plt.title('Sex vs defects')
# Out:
# Text(0.5, 1.0, 'Sex vs defects')

# %%
cd = pd.crosstab(df['sex'],df['target'])
sns.heatmap(cd)
plt.title('Sex vs diseased ')
# Out:
# Text(0.5, 1.0, 'Sex vs diseased ')

# %%
cd = pd.crosstab(df['cp'],df['fbs'])
sns.heatmap(cd)
plt.title('Chest pain type vs blood sugar level')
# Out:
# Text(0.5, 1.0, 'Chest pain type vs blood sugar level')

# %% [markdown]
# Observation
# - Maximum male and female have typical angina
# - Minimum female have asyptomatic
# - maximum male have no bood sugar more then 120mg/dl
# - Very few femal have exercise induced angina
# - More then 100 males have 0 number of major vessels
# - maximum male have disease

# %%
cd = pd.crosstab(df['cp'],df['restecg'])
sns.heatmap(cd)
plt.title('Chest pain type vs  resting electrocardiographic results ')
# Out:
# Text(0.5, 1.0, 'Chest pain type vs  resting electrocardiographic results ')

# %%
cd = pd.crosstab(df['cp'],df['exang'])
sns.heatmap(cd)
plt.title('Chest pain type vs exercise induced angina ')
# Out:
# Text(0.5, 1.0, 'Chest pain type vs exercise induced angina ')

# %%
cd = pd.crosstab(df['cp'],df['slope'])
sns.heatmap(cd)
plt.title('Chest pain type vs slope')
# Out:
# Text(0.5, 1.0, 'Chest pain type vs slope')

# %%
cd = pd.crosstab(df['cp'],df['ca'])
sns.heatmap(cd,annot = True)
plt.title('Chest pain type vs number of vessels')
# Out:
# Text(0.5, 1.0, 'Chest pain type vs number of vessels')

# %%
cd = pd.crosstab(df['cp'],df['thal'])
sns.heatmap(cd,annot = True)
plt.title('Chest pain type vs defects')
# Out:
# Text(0.5, 1.0, 'Chest pain type vs defects')

# %%
cd = pd.crosstab(df['cp'],df['target'])
sns.heatmap(cd,annot = True)
plt.title('Chest pain type vs diseased people')
# Out:
# Text(0.5, 1.0, 'Chest pain type vs diseased people')

# %% [markdown]
# Observation
# - People with typical angina have no blood sugar more then 120mg/dl
# - People with typical angina have normal electrocardiographic result
# - People with typical angina have exercise induced angina
# - People with chest pain have more upslopping in ST segment
# - Most people with chest pain have 0 major vessels
# - Most people with chest pain have normal or fixed defects
# - Most people with chest pain are diseased

# %%
cd = pd.crosstab(df['fbs'],df['ca'])
sns.heatmap(cd,annot = True)
plt.title('Blood sugar level vs number of vessels')
# Out:
# Text(0.5, 1.0, 'Blood sugar level vs number of vessels')

# %%
cd = pd.crosstab(df['fbs'],df['target'])
sns.heatmap(cd,annot = True)
plt.title('Blood sugar level vs diseased people')
# Out:
# Text(0.5, 1.0, 'Blood sugar level vs diseased people')

# %%
cd = pd.crosstab(df['fbs'],df['thal'])
sns.heatmap(cd,annot = True)
plt.title('Blood sugar level vs defects')
# Out:
# Text(0.5, 1.0, 'Blood sugar level vs defects')

# %%
cd = pd.crosstab(df['fbs'],df['slope'])
sns.heatmap(cd)
plt.title('Blood sugar level vs slope')
# Out:
# Text(0.5, 1.0, 'Blood sugar level vs slope')

# %%
cd = pd.crosstab(df['fbs'],df['exang'])
sns.heatmap(cd)
plt.title('Blood sugar level vs exercise induced angina')
# Out:
# Text(0.5, 1.0, 'Blood sugar level vs exercise induced angina')

# %%
cd = pd.crosstab(df['fbs'],df['restecg'])
sns.heatmap(cd)
plt.title('Blood sugar level vs resting electrocardiographic results')
# Out:
# Text(0.5, 1.0, 'Blood sugar level vs resting electrocardiographic results')

# %%
cd = pd.crosstab(df['exang'],df['restecg'])
sns.heatmap(cd)
plt.title('Exercise induced angina vs resting electrocardiographic results')
# Out:
# Text(0.5, 1.0, 'Exercise induced angina vs resting electrocardiographic results')

# %%
cd = pd.crosstab(df['slope'],df['restecg'])
sns.heatmap(cd)
plt.title('Slope vs resting electrocardiographic results')
# Out:
# Text(0.5, 1.0, 'Slope vs resting electrocardiographic results')

# %%
cd = pd.crosstab(df['ca'],df['restecg'])
sns.heatmap(cd)
plt.title('Number of major vessels vs resting electrocardiographic results')
# Out:
# Text(0.5, 1.0, 'Number of major vessels vs resting electrocardiographic results')

# %%
cd = pd.crosstab(df['thal'],df['restecg'])
sns.heatmap(cd)
plt.title('Defects vs resting electrocardiographic results')
# Out:
# Text(0.5, 1.0, 'Defects vs resting electrocardiographic results')

# %%
cd = pd.crosstab(df['target'],df['restecg'])
sns.heatmap(cd)
plt.title(' Diseased people vs resting electrocardiographic results')
# Out:
# Text(0.5, 1.0, ' Diseased people vs resting electrocardiographic results')

# %% [markdown]
# Observation
# - People with blood sugar less then 120mg/dl are diseased
# - People with blood sugar less then 120mg/dl have reversable defects
# - People with blood sugar less then 120mg/dl have flat and downslopping in ST segment
# - People with blood sugar less then 120mg/dl have no exercise induced angina
# - People with blood sugar less then 120mg/dl have normal and abnormality in ST segment
# - Very few people with blood sugar more then 120mg/dl have exercise induced angina
# - People with normal electrocardiographic result have exercise induced angina
# - People with normal electrocardiographic result have flat and downsloping
# - People with normal electrocardiographic result have 0 number of major vessels
# - People with normal electrocardiographic result have reversable defects
# - Most people with ST-T wave abnormility are diseased

# %%
cd = pd.crosstab(df['exang'],df['slope'])
sns.heatmap(cd)
plt.title('Exercise induced angina vs slope')
# Out:
# Text(0.5, 1.0, 'Exercise induced angina vs slope')

# %%
cd = pd.crosstab(df['exang'],df['ca'])
sns.heatmap(cd)
plt.title('Exercise induced angina vs number of major vessels')
# Out:
# Text(0.5, 1.0, 'Exercise induced angina vs number of major vessels')

# %%
cd = pd.crosstab(df['exang'],df['thal'])
sns.heatmap(cd)
plt.title('Exercise induced angina vs defects')
# Out:
# Text(0.5, 1.0, 'Exercise induced angina vs defects')

# %%
cd = pd.crosstab(df['exang'],df['target'])
sns.heatmap(cd)
plt.title('Exercise induced angina vs diseased people')
# Out:
# Text(0.5, 1.0, 'Exercise induced angina vs diseased people')

# %%
cd = pd.crosstab(df['slope'],df['ca'])
sns.heatmap(cd)
plt.title('Slope vs number of major vessels')
# Out:
# Text(0.5, 1.0, 'Slope vs number of major vessels')

# %%
cd = pd.crosstab(df['slope'],df['thal'])
sns.heatmap(cd)
plt.title('Slope vs defects')
# Out:
# Text(0.5, 1.0, 'Slope vs defects')

# %%
cd = pd.crosstab(df['slope'],df['target'])
sns.heatmap(cd)
plt.title('Slope vs diseased people')
# Out:
# Text(0.5, 1.0, 'Slope vs diseased people')

# %%
cd = pd.crosstab(df['ca'],df['thal'])
sns.heatmap(cd)
plt.title('Number of major vessels vs defects')
# Out:
# Text(0.5, 1.0, 'Number of major vessels vs defects')

# %%
cd = pd.crosstab(df['ca'],df['target'])
sns.heatmap(cd)
plt.title('Number of major vessels vs diseased people')
# Out:
# Text(0.5, 1.0, 'Number of major vessels vs diseased people')

# %%
cd = pd.crosstab(df['target'],df['thal'])
sns.heatmap(cd)
plt.title('Diseased people vs defects')
# Out:
# Text(0.5, 1.0, 'Diseased people vs defects')

# %% [markdown]
# Observation
# - People with no exercise angina have downslopping
# - People with no exercise angina have 0 major vessels
# - People with no exercise angina have more reversable defects
# - People with no exercise angina haveery few people with exercise induced angina are diseased
# - People with 0 major vessels have downslopping
# - People with 0 major vessels have revesable defects
# - People with 0 major vessels are diseased
# - People with downslopping have reversable defects
# - People with downslopping are diseased
# - People with reversable defects are more diseased

# %%
sns.pairplot(df)

# %% [markdown]
# Oservation
# - People of age 40 -60 years have blood presure between 120-140mg/dl
# - People of age 50 -70 years have cholestrol between 200 and 300mg/dl
# - People of age 50 -60 years have 140-180 maximum heart rate
# - More people have no  ST depression induced by exercise relative to rest
# - People with blood presure between 120-140mg/dl have no  ST depression induced by exercise relative to rest
# - People with blood presure between 120-140mg/dl have 140-180 maximum heart rate
# - People with blood presure between 120-140mg/dl have cholestrol between 200 and 300mg/dl
# - People with cholestrol between 200 and 300mg/dl have no  ST depression induced by exercise relative to rest
# - People with cholestrol between 200 and 300mg/dl have 140-180 maximum heart rate
# - People with 140-180 maximum heart rate have no  ST depression induced by exercise relative to rest

# %%
sns.barplot(x='sex',y='age',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x='cp',y='age',data=df)
# Out:
# <Axes: xlabel='cp', ylabel='age'>

# %%
sns.barplot(x='fbs',y='age',data=df)
# Out:
# <Axes: xlabel='fbs', ylabel='age'>

# %%
sns.barplot(x='restecg',y='age',data=df)
# Out:
# <Axes: xlabel='restecg', ylabel='age'>

# %%
sns.barplot(x='exang',y='age',data=df)
# Out:
# <Axes: xlabel='exang', ylabel='age'>

# %%
sns.barplot(x='slope',y='age',data=df)
# Out:
# <Axes: xlabel='slope', ylabel='age'>

# %%
sns.barplot(x='ca',y='age',data=df)
# Out:
# <Axes: xlabel='ca', ylabel='age'>

# %%
sns.barplot(x='thal',y='age',data=df)
# Out:
# <Axes: xlabel='thal', ylabel='age'>

# %%
sns.barplot(x='target',y='age',data=df)
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.barplot(x='sex',y='trestbps',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='trestbps'>

# %%
sns.barplot(x='cp',y='trestbps',data=df)
# Out:
# <Axes: xlabel='cp', ylabel='trestbps'>

# %%
sns.barplot(x='fbs',y='trestbps',data=df)
# Out:
# <Axes: xlabel='fbs', ylabel='trestbps'>

# %%
sns.barplot(x='restecg',y='trestbps',data=df)
# Out:
# <Axes: xlabel='restecg', ylabel='trestbps'>

# %%
sns.barplot(x='exang',y='trestbps',data=df)
# Out:
# <Axes: xlabel='exang', ylabel='trestbps'>

# %%
sns.barplot(x='slope',y='trestbps',data=df)
# Out:
# <Axes: xlabel='slope', ylabel='trestbps'>

# %%
sns.barplot(x='ca',y='trestbps',data=df)
# Out:
# <Axes: xlabel='ca', ylabel='trestbps'>

# %%
sns.barplot(x='thal',y='trestbps',data=df)
# Out:
# <Axes: xlabel='thal', ylabel='trestbps'>

# %%
sns.barplot(x='target',y='trestbps',data=df)
# Out:
# <Axes: xlabel='target', ylabel='trestbps'>

# %%
sns.barplot(x='sex',y='chol',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='chol'>

# %%
sns.barplot(x='cp',y='chol',data=df)
# Out:
# <Axes: xlabel='cp', ylabel='chol'>

# %%
sns.barplot(x='fbs',y='chol',data=df)
# Out:
# <Axes: xlabel='fbs', ylabel='chol'>

# %%
sns.barplot(x='restecg',y='chol',data=df)
# Out:
# <Axes: xlabel='restecg', ylabel='chol'>

# %%
sns.barplot(x='exang',y='chol',data=df)
# Out:
# <Axes: xlabel='exang', ylabel='chol'>

# %%
sns.barplot(x='slope',y='chol',data=df)
# Out:
# <Axes: xlabel='slope', ylabel='chol'>

# %%
sns.barplot(x='ca',y='chol',data=df)
# Out:
# <Axes: xlabel='ca', ylabel='chol'>

# %%
sns.barplot(x='thal',y='chol',data=df)
# Out:
# <Axes: xlabel='thal', ylabel='chol'>

# %%
sns.barplot(x='target',y='chol',data=df)
# Out:
# <Axes: xlabel='target', ylabel='chol'>

# %%
sns.barplot(x='sex',y='thalach',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='thalach'>

# %%
sns.barplot(x='cp',y='thalach',data=df)
# Out:
# <Axes: xlabel='cp', ylabel='thalach'>

# %%
sns.barplot(x='fbs',y='thalach',data=df)
# Out:
# <Axes: xlabel='fbs', ylabel='thalach'>

# %%
sns.barplot(x='restecg',y='thalach',data=df)
# Out:
# <Axes: xlabel='restecg', ylabel='thalach'>

# %%
sns.barplot(x='exang',y='thalach',data=df)
# Out:
# <Axes: xlabel='exang', ylabel='thalach'>

# %%
sns.barplot(x='slope',y='thalach',data=df)
# Out:
# <Axes: xlabel='slope', ylabel='thalach'>

# %%
sns.barplot(x='ca',y='thalach',data=df)
# Out:
# <Axes: xlabel='ca', ylabel='thalach'>

# %%
sns.barplot(x='thal',y='thalach',data=df)
# Out:
# <Axes: xlabel='thal', ylabel='thalach'>

# %%
sns.barplot(x='target',y='thalach',data=df)
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
sns.barplot(x='sex',y='oldpeak',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='oldpeak'>

# %%
sns.barplot(x='cp',y='oldpeak',data=df)
# Out:
# <Axes: xlabel='cp', ylabel='oldpeak'>

# %%
sns.barplot(x='fbs',y='oldpeak',data=df)
# Out:
# <Axes: xlabel='fbs', ylabel='oldpeak'>

# %%
sns.barplot(x='restecg',y='oldpeak',data=df)
# Out:
# <Axes: xlabel='restecg', ylabel='oldpeak'>

# %%
sns.barplot(x='exang',y='oldpeak',data=df)
# Out:
# <Axes: xlabel='exang', ylabel='oldpeak'>

# %%
sns.barplot(x='slope',y='oldpeak',data=df)
# Out:
# <Axes: xlabel='slope', ylabel='oldpeak'>

# %%
sns.barplot(x='ca',y='oldpeak',data=df)
# Out:
# <Axes: xlabel='ca', ylabel='oldpeak'>

# %%
sns.barplot(x='thal',y='oldpeak',data=df)
# Out:
# <Axes: xlabel='thal', ylabel='oldpeak'>

# %%
sns.barplot(x='target',y='oldpeak',data=df)
# Out:
# <Axes: xlabel='target', ylabel='oldpeak'>
